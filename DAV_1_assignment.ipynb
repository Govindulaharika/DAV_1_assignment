# %%
import pandas as pd
df=pd.read_csv("earthquake_1995-2023.csv")
print("rows and columns",df.shape)
df.head()
# Out:
# rows and columns (1000, 19)
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16/08/2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19/07/2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17/07/2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16/07/2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16/07/2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
# ...

# %%
df.info()
print(df.duplicated().sum())
dupe_mask=df.duplicated(subset=["title","date_time"],keep=False)
print("rows involved in a title+data_time",dupe_mask.sum())
df[dupe_mask].sort_values("title")[["title","date_time","magnitude","country"]]
before=len(df)
df=df.drop_duplicates(subset=["title","date_time"],keep="first").reset_index(drop=True)
after=len(df)
print(f"record{before-after} duplicate row(s)")
print("rows now :",after)
import numpy as np
for col in ["cdi","gap","dmin","nst"]:
  df[col]=df[col].replace(0,np.nan)
print("missing values now visible")
print(df[["cdi","gap","dmin","nst"]].isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   magnitude  1000 non-null   float64
#  2   date_time  1000 non-null   object
#  3   cdi        1000 non-null   int64
#  4   mmi        1000 non-null   int64
#  5   alert      449 non-null    object
#  6   tsunami    1000 non-null   int64
#  7   sig        1000 non-null   int64
#  8   net        1000 non-null   object
#  9   nst        1000 non-null   int64
#  10  dmin       1000 non-null   float64
#  11  gap        1000 non-null   float64
#  12  magType    1000 non-null   object
#  13  depth      1000 non-null   float64
#  14  latitude   1000 non-null   float64
#  15  longitude  1000 non-null   float64
#  16  location   994 non-null    object
#  17  continent  284 non-null    object
#  18  country    651 non-null    object
# ...

# %%
missing_count = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_report = pd.DataFrame({
    "Missing Count": missing_count,
    "Missing Percentage": missing_percent
})

print(missing_report)
# Out:
#            Missing Count  Missing Percentage
# title                  0            0.000000
# magnitude              0            0.000000
# date_time              0            0.000000
# cdi                  395           39.579158
# mmi                    0            0.000000
# alert                549           55.010020
# tsunami                0            0.000000
# sig                    0            0.000000
# net                    0            0.000000
# nst                  519           52.004008
# dmin                 586           58.717435
# gap                  252           25.250501
# magType                0            0.000000
# depth                  0            0.000000
# latitude               0            0.000000
# longitude              0            0.000000
# location               6            0.601202
# continent            714           71.543086
# country              347           34.769539

# %%
import matplotlib.pyplot as plt

for col in ["cdi", "gap", "nst", "dmin"]:
    print(col, "skewness:", df[col].skew())

    plt.figure(figsize=(6, 4))
    plt.hist(df[col].dropna(), bins=30)
    plt.title("Distribution of " + col)
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
df["alert"].value_counts().plot(kind="bar")
plt.xlabel("Alert Level")
plt.ylabel("Number of Earthquakes")
plt.title("Earthquakes by Alert Level")
plt.show()
# Out:
# cdi skewness: -0.32333961422130675
# gap skewness: 4.885701324053703
# nst skewness: 0.007851413023867444
# dmin skewness: 1.9997583308140012

# %%
for col in ["cdi", "gap", "nst", "dmin"]:
    print("\n", col)
    print("Mean  :", df[col].mean())
    print("Median:", df[col].median())
    print("Skewness:", df[col].skew())
print("Missing alert:", df["alert"].isnull().sum())

alert_mode = df["alert"].mode()[0]

print("Alert mode:", alert_mode)

df["alert"] = df["alert"].fillna(alert_mode)

print("Missing alert after filling:",
      df["alert"].isnull().sum())
# Out:
#  cdi
# Mean  : 5.978441127694859
# Median: 6.0
# Skewness: -0.32333961422130675
#
#  gap
# Mean  : 27.4963672922252
# Median: 21.25
# Skewness: 4.885701324053703
#
#  nst
# Mean  : 404.74947807933194
# Median: 411.0
# Skewness: 0.007851413023867444
#
#  dmin
# Mean  : 2.7310060048543687
# Median: 1.9915
# Skewness: 1.9997583308140012
# Missing alert: 549
# Alert mode: green
# Missing alert after filling: 0

# %%
for col in ["cdi", "gap", "nst", "dmin"]:
    df[col] = df[col].fillna(df[col].median())

print("Numeric missing values filled")
categorical_cols = ["alert", "location", "continent", "country"]

for col in categorical_cols:
    df[col] = df[col].fillna("Unknown")

print("Categorical missing values filled")
print("Remaining missing values:")
print(df.isnull().sum())

print("\nTotal missing values:", df.isnull().sum().sum())
# Out:
# Numeric missing values filled
# Categorical missing values filled
# Remaining missing values:
# title        0
# magnitude    0
# date_time    0
# cdi          0
# mmi          0
# alert        0
# tsunami      0
# sig          0
# net          0
# nst          0
# dmin         0
# gap          0
# magType      0
# depth        0
# latitude     0
# longitude    0
# location     0
# continent    0
# country      0
# dtype: int64
#
# Total missing values: 0
